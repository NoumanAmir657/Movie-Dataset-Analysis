# %%
import pandas as pd
from pandas import Series
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
movie_df = pd.read_csv("IMDB-Movie-Data.csv")

# %%
movie_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movie_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
movie_df.rename(columns = {'Rank':'Index', 'Runtime (Minutes)':'Runtime', 'Revenue (Millions)': 'Revenue'}, inplace = True) #change Rank column name to Index

# %%
movie_df
# Out:
#      Index                    Title                     Genre  \
# 0        1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1        2               Prometheus  Adventure,Mystery,Sci-Fi
# 2        3                    Split           Horror,Thriller
# 3        4                     Sing   Animation,Comedy,Family
# 4        5            Suicide Squad  Action,Adventure,Fantasy
# ..     ...                      ...                       ...
# 995    996     Secret in Their Eyes       Crime,Drama,Mystery
# 996    997          Hostel: Part II                    Horror
# 997    998   Step Up 2: The Streets       Drama,Music,Romance
# 998    999             Search Party          Adventure,Comedy
# 999   1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### Drop Rows which have incomplete data or NaN values.

# %% [markdown]
# ### Drop null values of Revenue (Millions) and Metascore

# %%
movie_df.dropna(inplace=True)
movie_df.reset_index(drop=True, inplace=True)

# %%
movie_df
# Out:
#      Index                     Title                     Genre  \
# 0        1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1        2                Prometheus  Adventure,Mystery,Sci-Fi
# 2        3                     Split           Horror,Thriller
# 3        4                      Sing   Animation,Comedy,Family
# 4        5             Suicide Squad  Action,Adventure,Fantasy
# ..     ...                       ...                       ...
# 833    994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834    995                 Project X                    Comedy
# 835    997           Hostel: Part II                    Horror
# 836    998    Step Up 2: The Streets       Drama,Music,Romance
# 837   1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        838 non-null    int64
#  1   Title        838 non-null    object
#  2   Genre        838 non-null    object
#  3   Description  838 non-null    object
#  4   Director     838 non-null    object
#  5   Actors       838 non-null    object
#  6   Year         838 non-null    int64
#  7   Runtime      838 non-null    int64
#  8   Rating       838 non-null    float64
#  9   Votes        838 non-null    int64
#  10  Revenue      838 non-null    float64
#  11  Metascore    838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 78.7+ KB

# %%
len(movie_df.Director.unique())
# Out:
# 524

# %%
movie_df.corr(method = 'pearson')
# Out:
#               Index      Year   Runtime    Rating     Votes   Revenue  \
# Index      1.000000 -0.312809 -0.254783 -0.243125 -0.303284 -0.273170
# Year      -0.312809  1.000000 -0.101933 -0.145703 -0.362445 -0.129198
# Runtime   -0.254783 -0.101933  1.000000  0.374566  0.399298  0.281721
# Rating    -0.243125 -0.145703  0.374566  1.000000  0.517452  0.217106
# Votes     -0.303284 -0.362445  0.399298  0.517452  1.000000  0.636833
# Revenue   -0.273170 -0.129198  0.281721  0.217106  0.636833  1.000000
# Metascore -0.195909 -0.062303  0.221397  0.672731  0.332674  0.142397
#
#            Metascore
# Index      -0.195909
# Year       -0.062303
# Runtime     0.221397
# Rating      0.672731
# Votes       0.332674
# Revenue     0.142397
# Metascore   1.000000

# %% [markdown]
# ### Runtime vs Rating

# %%
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Runtime (Minutes)")
plt.ylabel("Rating")
sns.scatterplot(x = movie_df.Runtime, y = movie_df.Rating)
# Out:
# <AxesSubplot:xlabel='Runtime (Minutes)', ylabel='Rating'>

# %% [markdown]
# ### We see that most of the movies that last between 85 to 120 minutes have their rating concentrated between 5 and 8.5.

# %%
plt.figure(figsize=(12, 6))
plt.hist(movie_df.Runtime)
# Out:
# (array([  1.,  47., 196., 213., 194.,  93.,  51.,  27.,  13.,   3.]),
#  array([ 66. ,  78.1,  90.2, 102.3, 114.4, 126.5, 138.6, 150.7, 162.8,
#         174.9, 187. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Most of the movies last between 114 to 126 minutes.

# %%
x = movie_df.Runtime.idxmax()
print(movie_df.Title[x])
print(movie_df.Runtime[x])
# Out:
# The Hateful Eight
# 187

# %% [markdown]
# ### The movie with the longest runtime of 3 hour 7 minute is 'The Hateful Eight'.

# %%
x = movie_df.Runtime.idxmin()
print(movie_df.Title[x])
print(movie_df.Runtime[x])
# Out:
# Ma vie de Courgette
# 66

# %% [markdown]
# ### The movie with the shortest runtime of 1 hour and 6 minutes is 'Ma vie de Courgette'

# %% [markdown]
# ### Runtime and Metascore

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Runtime (Minutes)")
plt.ylabel("Metascore")
sns.scatterplot(x = movie_df.Runtime, y = movie_df.Metascore)
# Out:
# <AxesSubplot:xlabel='Runtime (Minutes)', ylabel='Metascore'>

# %% [markdown]
# ### The scatterplot clearly shows that the rating of critics(Metascore) is more spread than the Rating.

# %% [markdown]
# ### Rating and Revenue

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Rating")
plt.ylabel("Revenue")
sns.scatterplot(x = movie_df.Rating, y = movie_df.Revenue)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Revenue'>

# %% [markdown]
# ### Movies with high rating, generated more revenue according to the graph.

# %%
x = movie_df.Rating.idxmax()
print(movie_df.Title[x])
print(movie_df.Rating[x])
# Out:
# The Dark Knight
# 9.0

# %% [markdown]
# ### 'The Dark Knight' was rated 9. The highest rated movie in this dataset.

# %%
x = movie_df.Revenue.idxmax()
print(movie_df.Title[x])
print(movie_df.Revenue[x])
# Out:
# Star Wars: Episode VII - The Force Awakens
# 936.63

# %% [markdown]
# ### 'Star Wars: Episode VII - The Force Awakens' generated the highest revenue of 936.63 Billion.

# %% [markdown]
# ### Metascore and Revenue

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Metascore")
plt.ylabel("Revenue")
sns.scatterplot(x = movie_df.Metascore, y = movie_df.Revenue)
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Revenue'>

# %% [markdown]
# ### As seen again Metascore is more spread than Rating. Movies with high Metascore generated more revenue.

# %% [markdown]
# ### Rating and Metascore

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Metascore")
plt.ylabel("Rating")
sns.scatterplot(x = movie_df.Metascore, y = movie_df.Rating)
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Rating'>

# %% [markdown]
# ### The graph gives a clear indication that, Movies with high metascore have high Rating. Positive Correlation.

# %%
x = movie_df.Metascore.idxmax()
print(movie_df.Title[x])
print(movie_df.Metascore[x])
# Out:
# Boyhood
# 100.0

# %% [markdown]
# ### Highest Metascore is for 'Boyhood'. 100/100

# %% [markdown]
# ### Rating and Votes

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("Rating")
plt.ylabel("Votes")
sns.scatterplot(x = movie_df.Rating, y = movie_df.Votes/1000000)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Votes'>

# %% [markdown]
# ### The people voted for those movies more that they loved more.

# %% [markdown]
# # Distribution of different Columns.

# %%
movie_df.columns
# Out:
# Index(['Index', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))
axes[0][0].hist(movie_df.Year)
axes[0][0].set_xlabel('Year')

axes[0][1].hist(movie_df.Runtime)
axes[0][1].set_xlabel('Runtime')

axes[0][2].hist(movie_df.Rating)
axes[0][2].set_xlabel('Rating')

axes[1][0].hist(movie_df.Votes)
axes[1][0].set_xlabel('Votes')

axes[1][1].hist(movie_df.Revenue)
axes[1][1].set_xlabel('Revenue')

axes[1][2].hist(movie_df.Metascore)
axes[1][2].set_xlabel('Metascore')

plt.tight_layout(pad=2);

# %% [markdown]
# ### Most of the movies(above 300) in this dataset are released in 2016.
# ### Most of the movies have 114 to 126 runtime.
# ### Most of the movies lie between 6 to 7 rating.
# ### Movies have mostly generated Revenue between 0 and 100 million
# ### Metascore is almost normally distributed. 60/100

# %% [markdown]
# ### Adding Genres list to movie_df

# %%
movie_df
# Out:
#      Index                     Title                     Genre  \
# 0        1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1        2                Prometheus  Adventure,Mystery,Sci-Fi
# 2        3                     Split           Horror,Thriller
# 3        4                      Sing   Animation,Comedy,Family
# 4        5             Suicide Squad  Action,Adventure,Fantasy
# ..     ...                       ...                       ...
# 833    994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834    995                 Project X                    Comedy
# 835    997           Hostel: Part II                    Horror
# 836    998    Step Up 2: The Streets       Drama,Music,Romance
# 837   1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
s = movie_df['Genre'].str.split(',').apply(Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'Genre'
del movie_df['Genre']
movie_df1 = movie_df.join(s)

# %%
movie_df1
# Out:
#      Index                    Title  \
# 0        1  Guardians of the Galaxy
# 0        1  Guardians of the Galaxy
# 0        1  Guardians of the Galaxy
# 1        2               Prometheus
# 1        2               Prometheus
# ..     ...                      ...
# 836    998   Step Up 2: The Streets
# 836    998   Step Up 2: The Streets
# 837   1000               Nine Lives
# 837   1000               Nine Lives
# 837   1000               Nine Lives
#
#                                            Description          Director  \
# 0    A group of intergalactic criminals are forced ...        James Gunn
# 0    A group of intergalactic criminals are forced ...        James Gunn
# 0    A group of intergalactic criminals are forced ...        James Gunn
# 1    Following clues to the origin of mankind, a te...      Ridley Scott
# 1    Following clues to the origin of mankind, a te...      Ridley Scott
# ..                                                 ...               ...
# ...

# %% [markdown]
# ### Grouping by Movie's Genres

# %%
movie_df_groups = (pd.DataFrame(movie_df1.groupby('Genre').Title.nunique())).sort_values('Title', ascending=False)

# %%
movie_df_groups
# Out:
#            Title
# Genre
# Drama        419
# Action       277
# Comedy       250
# Adventure    244
# Thriller     148
# Crime        126
# Romance      120
# Sci-Fi       107
# Fantasy       92
# Horror        87
# Mystery       86
# Biography     67
# Family        48
# Animation     45
# History       25
# Music         15
# Sport         15
# War           10
# Musical        5
# Western        4

# %%
movie_df_groups[['Title']].plot.barh(stacked=True, title = 'No. of Movies According to Genre', figsize=(8, 8));

# %% [markdown]
# ## Revenue and Genre

# %%
action_df = movie_df1[movie_df1.Genre == 'Action']
adv_df = movie_df1[movie_df1.Genre == 'Adventure']
fantasy_df = movie_df1[movie_df1.Genre == 'Fantasy']
scifi_df = movie_df1[movie_df1.Genre == 'Sci-Fi']
thriller_df = movie_df1[movie_df1.Genre == 'Thriller']
rom_df = movie_df1[movie_df1.Genre == 'Romance']
ani_df = movie_df1[movie_df1.Genre == 'Animation']
comedy_df = movie_df1[movie_df1.Genre == 'Comedy']
fam_df = movie_df1[movie_df1.Genre == 'Family']
musical_df = movie_df1[movie_df1.Genre == 'Musical']
mys_df = movie_df1[movie_df1.Genre == 'Mystery']
western_df = movie_df1[movie_df1.Genre == 'Western']
drama_df = movie_df1[movie_df1.Genre == 'Drama']
hist_df = movie_df1[movie_df1.Genre == 'History']
sport_df = movie_df1[movie_df1.Genre == 'Sport']
crime_df = movie_df1[movie_df1.Genre == 'Crime']
horr_df = movie_df1[movie_df1.Genre == 'Horror']
war_df = movie_df1[movie_df1.Genre == 'War']
bio_df = movie_df1[movie_df1.Genre == 'Biography']
music_df = movie_df1[movie_df1.Genre == 'Music']

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Revenue according to Genre')

plt.hist([action_df.Revenue, adv_df.Revenue, fantasy_df.Revenue, scifi_df.Revenue, thriller_df.Revenue], stacked=True);

plt.legend(['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller']);

# %% [markdown]
# ### Action Genre has generated more revenue.

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Revenue according to Genre')

plt.hist([rom_df.Revenue, ani_df.Revenue, comedy_df.Revenue, fam_df.Revenue, musical_df.Revenue], stacked=True);

plt.legend(['Romance', 'Animation', 'Comedy', 'Family', 'Musical']);

# %% [markdown]
# ### Comedy generated more Revenue.

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Revenue according to Genre')

plt.hist([mys_df.Revenue, western_df.Revenue, drama_df.Revenue, hist_df.Revenue, sport_df.Revenue], stacked=True);

plt.legend(['Mystery', 'Western', 'Drama', 'History', 'Sport']);

# %% [markdown]
# ### Drama generated more revenue.

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Revenue according to Genre')

plt.hist([crime_df.Revenue, horr_df.Revenue, war_df.Revenue, bio_df.Revenue, music_df.Revenue], stacked=True);

plt.legend(['Crime', 'Horror', 'War', 'Biography', 'Music']);

# %% [markdown]
# ### Crime generated more revenue.

# %% [markdown]
# ### Overall Action, Comedy, Drama and Crime generated more Revenue.

# %% [markdown]
# ## Rating and Genre

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Rating according to Genre')

plt.hist([action_df.Rating, adv_df.Rating, fantasy_df.Rating, scifi_df.Rating, thriller_df.Rating], stacked=True);

plt.legend(['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Rating according to Genre')

plt.hist([rom_df.Rating, ani_df.Rating, comedy_df.Rating, fam_df.Rating, musical_df.Rating], stacked=True);

plt.legend(['Romance', 'Animation', 'Comedy', 'Family', 'Musical']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Rating according to Genre')

plt.hist([mys_df.Rating, western_df.Rating, drama_df.Rating, hist_df.Rating, sport_df.Rating], stacked=True);

plt.legend(['Mystery', 'Western', 'Drama', 'History', 'Sport']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Rating according to Genre')

plt.hist([crime_df.Rating, horr_df.Rating, war_df.Rating, bio_df.Rating, music_df.Rating], stacked=True);

plt.legend(['Crime', 'Horror', 'War', 'Biography', 'Music']);

# %% [markdown]
# ### Action, Adventure, Thriller, Sci-Fi, Comedy, Drama and Biography were more liked by people as they have more movies with Rating ranging from 8 to 9.

# %% [markdown]
# plt.figure(figsize=(12, 6))
# plt.title('Distribution of Rating according to Genre')
#
# plt.hist([action_df.Rating, adv_df.Rating, fantasy_df.Rating, scifi_df.Rating, thriller_df.Rating, rom_df.Rating, ani_df.Rating, comedy_df.Rating,
#           fam_df.Rating, musical_df.Rating, mys_df.Rating, western_df.Rating, drama_df.Rating, hist_df.Rating,
#           sport_df.Rating, crime_df.Rating, horr_df.Rating, war_df.Rating, bio_df.Rating, music_df.Rating], stacked=True);
#
# plt.legend(['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller', 'Romance', 'Animation', 'Comedy', 'Family', 'Musical', 'Mystery', 'Western', 'Drama', 'History',
#             'Sport', 'Crime', 'Horror', 'War', 'Biography', 'Music']);

# %% [markdown]
# ## Metascore and Genre

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Metascore according to Genre')

plt.hist([action_df.Metascore, adv_df.Metascore, fantasy_df.Metascore, scifi_df.Metascore, thriller_df.Metascore], stacked=True);

plt.legend(['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Metascore according to Genre')

plt.hist([rom_df.Metascore, ani_df.Metascore, comedy_df.Metascore, fam_df.Metascore, musical_df.Metascore], stacked=True);

plt.legend(['Romance', 'Animation', 'Comedy', 'Family', 'Musical']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Metascore according to Genre')

plt.hist([mys_df.Metascore, western_df.Metascore, drama_df.Metascore, hist_df.Metascore, sport_df.Metascore], stacked=True);

plt.legend(['Mystery', 'Western', 'Drama', 'History', 'Sport']);

# %%
plt.figure(figsize=(12, 6))
plt.title('Distribution of Metascore according to Genre')

plt.hist([crime_df.Metascore, horr_df.Metascore, war_df.Metascore, bio_df.Metascore, music_df.Metascore], stacked=True);

plt.legend(['Crime', 'Horror', 'War', 'Biography', 'Music']);

# %% [markdown]
# ### Overall Action, Adventure, Thriller, Comedy, Animation, Drama, Crime and Biography have high Metascores.

# %% [markdown]
# ### Metascore and Rating with respect to each Genre

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=action_df.Rating, y=action_df.Metascore, s=100);
sns.scatterplot(x=adv_df.Rating, y=adv_df.Metascore, s=100);
sns.scatterplot(x=fantasy_df.Rating, y=fantasy_df.Metascore, s=100);
sns.scatterplot(x=scifi_df.Rating, y=scifi_df.Metascore, s=100);
sns.scatterplot(x=thriller_df.Rating, y=thriller_df.Metascore, s=100);
plt.legend(['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller'])

# %% [markdown]
# ### The graph shows that Adventure and Thriller are the most popular movies according to Metascore and Rating

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=rom_df.Rating, y=rom_df.Metascore, s=100);
sns.scatterplot(x=ani_df.Rating, y=ani_df.Metascore, s=100);
sns.scatterplot(x=comedy_df.Rating, y=comedy_df.Metascore, s=100);
sns.scatterplot(x=fam_df.Rating, y=fam_df.Metascore, s=100);
sns.scatterplot(x=musical_df.Rating, y=musical_df.Metascore, s=100);
plt.legend(['Romance', 'Animation', 'Comedy', 'Family', 'Musical'])

# %% [markdown]
# ### Comedy have been the most liked by critics and audience.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=mys_df.Rating, y=mys_df.Metascore, s=100);
sns.scatterplot(x=western_df.Rating, y=western_df.Metascore, s=100);
sns.scatterplot(x=drama_df.Rating, y=drama_df.Metascore, s=100);
sns.scatterplot(x=hist_df.Rating, y=hist_df.Metascore, s=100);
sns.scatterplot(x=sport_df.Rating, y=sport_df.Metascore, s=100);
plt.legend(['Mystery', 'Western', 'Drama', 'History', 'Sport'])

# %% [markdown]
# ### Drama has been liked the most.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=crime_df.Rating, y=crime_df.Metascore, s=100);
sns.scatterplot(x=horr_df.Rating, y=horr_df.Metascore, s=100);
sns.scatterplot(x=war_df.Rating, y=war_df.Metascore, s=100);
sns.scatterplot(x=bio_df.Rating, y=bio_df.Metascore, s=100);
sns.scatterplot(x=music_df.Rating, y=music_df.Metascore, s=100);
plt.legend(['Crime', 'Horror', 'War', 'Biography', 'Music'])

# %% [markdown]
# ### Crime and Biography are liked most by critics and audience.
